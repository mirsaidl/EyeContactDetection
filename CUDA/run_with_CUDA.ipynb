# %%
# !conda activate --name gpu python=3.9
# !conda activate gpu # or connect kernel to gpu env
# !conda install -c conda-forge cudatoolkit=11.2 cudnn=8.1.0
# !pip install tensorflow==2.10 # must be below 2.11

# %%
# !pip install opencv-python pandas numpy mediapipe pynvml

# %%
import pathlib
import tensorflow as tf
import cv2
import mediapipe as mp
import numpy as np
import time
from datetime import datetime
import pandas as pd

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath

# %%
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(min_detection_confidence=0.5, min_tracking_confidence=0.5, max_num_faces=1)

def get_head_pose_direction(face_region):
    image_rgb = cv2.cvtColor(face_region, cv2.COLOR_BGR2RGB)
    image_rgb.flags.writeable = False
    results = face_mesh.process(image_rgb)
    image_rgb.flags.writeable = True
    face_2d = []
    if results.multi_face_landmarks:
        for face_landmarks in results.multi_face_landmarks:
            for idx, lm in enumerate(face_landmarks.landmark):
                x, y = int(lm.x * 100), int(lm.y * 100)
                if idx == 1:
                    nose_x, nose_y = x, y
                face_2d.append([x, y])
            if nose_x < 40:
                direction = "Left"
            elif nose_x > 60:
                direction = "Right"
            elif nose_y < 40:
                direction = "Up"
            elif nose_y > 60:
                direction = "Down"
            else:
                direction = "Forward"
            
            return direction


def load_models():
    # Create the face detector with GPU support
    detector = cv2.FaceDetectorYN.create(
        "models/face_detection_yunet_2023mar.onnx", "", (0, 0),
        backend_id=cv2.dnn.DNN_BACKEND_CUDA,
        target_id=cv2.dnn.DNN_TARGET_CUDA
    )

    model = tf.keras.models.load_model("models/model.h5", compile=False)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return detector, model

def enhance_image(image):
    image = cv2.fastNlMeansDenoisingColored(image, None, 10, 10, 7, 21)
    kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    image = cv2.filter2D(src=image, ddepth=-1, kernel=kernel)
    img_yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
    img_yuv[:, :, 0] = cv2.equalizeHist(img_yuv[:, :, 0])
    image = cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)
    
    return image

def detect_eye_contact(right_eye, left_eye, model):
    # Enhance images
    right_eye = enhance_image(right_eye)
    left_eye = enhance_image(left_eye)
    
    # Resize images and normalize pixel values
    right_eye = cv2.resize(right_eye, (60, 60)) / 255.0
    left_eye = cv2.resize(left_eye, (60, 60)) / 255.0
    
    # Convert to TensorFlow tensors
    right_eye_tensor = tf.convert_to_tensor(right_eye, dtype=tf.float32)
    left_eye_tensor = tf.convert_to_tensor(left_eye, dtype=tf.float32)
    
    # Expand dimensions to add batch dimension
    right_eye_tensor = tf.expand_dims(right_eye_tensor, axis=0)
    left_eye_tensor = tf.expand_dims(left_eye_tensor, axis=0)
    
    # Convert grayscale images to RGB if needed
    if right_eye_tensor.shape[-1] == 1:
        right_eye_tensor = tf.image.grayscale_to_rgb(right_eye_tensor)
    if left_eye_tensor.shape[-1] == 1:
        left_eye_tensor = tf.image.grayscale_to_rgb(left_eye_tensor)
    
    # Concatenate right and left eyes to form a batch
    batch = tf.concat([right_eye_tensor, left_eye_tensor], axis=0)
    
    # Move batch tensor to GPU if available
    if tf.test.is_gpu_available():
        with tf.device('/GPU:0'):
            predictions = model.predict(batch)
            print('with GPU')
    else:
        predictions = model.predict(batch)
    
    # Get predicted labels for right and left eyes
    labels = ['ClosingEye', 'EyeContact', 'LeftLook', 'RightLook']
    right_eye_pred_label = labels[int(predictions[0].argmax(axis=-1))]
    left_eye_pred_label = labels[int(predictions[1].argmax(axis=-1))]
    
    # Check if either eye predicts "EyeContact"
    return right_eye_pred_label == "EyeContact" or left_eye_pred_label == "EyeContact"

# %%
import pynvml

def gpu_working_check():
    pynvml.nvmlInit()
    handle = pynvml.nvmlDeviceGetHandleByIndex(0)  # Use index 0 for the first GPU
    gpu_info = pynvml.nvmlDeviceGetUtilizationRates(handle)
    print("GPU utilization:", gpu_info.gpu)
    pynvml.nvmlShutdown()

# %%
# Load the models
detector, model = load_models()

# Initialize variables for tracking eye contact time
user_eye_contact_data = []

# Initialize a user count
user_count = 0

# %%
def detectFacEye(image, conf, eye_crop_size=10):
    global user_count, start_time
    height, width, _ = image.shape
    detector.setInputSize((width, height))
    
    _, faces = detector.detect(image)
    if faces is not None:
        for face in faces:
            x, y, w, h = map(int, face[:4])
            
            right_eye_x, right_eye_y = int(face[4]), int(face[5])
            left_eye_x, left_eye_y = int(face[6]), int(face[7])
            right_eye = image[right_eye_y - eye_crop_size:right_eye_y + eye_crop_size, right_eye_x - eye_crop_size:right_eye_x + eye_crop_size]
            left_eye = image[left_eye_y - eye_crop_size:left_eye_y + eye_crop_size, left_eye_x - eye_crop_size:left_eye_x + eye_crop_size]
            eye_contact = detect_eye_contact(right_eye, left_eye, model)
            
            factor = 0.9
            expand_x = int(factor * w)
            expand_y = int(factor * h)
            new_x = max(0, x - expand_x)
            new_y = max(0, y - expand_y)
            new_w = min(width, w + 2 * expand_x)
            new_h = min(height, h + 2 * expand_y)

            face_region = image[new_y:new_y + new_h, new_x:new_x + new_w]
            face_region = enhance_image(face_region)
            # pred = detect_face_direction(face_region)
            pred = get_head_pose_direction(face_region)
            
            
            # if pred in ['Front', 'FrontLeft', 'FrontRight']:
            if pred in ["Forward", "Up"]:
                if eye_contact:
                    # Log the eye contact time for this user
                    elapsed_time = time.time() - start_time
                    current_time = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
                    user_count += 1
                    user_id = f"user_{user_count}"
                    
                    user_eye_contact_data.append({
                        "User ID": user_id,
                        "Eye Contact Duration (seconds)": elapsed_time,
                        "Date and Time": current_time
                    })
                    
                    color = (0, 255, 0)
                    text = f"EyeContact {user_id} {elapsed_time:.2f}s {pred}"
                    
                    start_time = time.time()
                else:
                        color = (0, 0, 255)
                        text = f"NoEyeContact {pred}"
            else:
                color = (0, 0, 255)
                text = f"NoEyeContact {pred}"
            
            cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
            cv2.rectangle(image, (right_eye_x - 5, right_eye_y - 5), (right_eye_x + 5, right_eye_y + 5), color, 2)
            cv2.rectangle(image, (left_eye_x - 5, left_eye_y - 5), (left_eye_x + 5, left_eye_y + 5), color, 2)
            cv2.putText(image, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2, cv2.LINE_AA)

# %%
def process_video(input_video_path, conf, eye_crop_size=10):
    global start_time
    cap = cv2.VideoCapture(input_video_path)
    
    #width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    #height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    #fourcc = cv2.VideoWriter_fourcc(*'XVID')
    #out = cv2.VideoWriter(output_video_path, fourcc, 20.0, (width, height))

    # Initialize start time
    start_time = time.time()
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        #gpu_working_check()  # Check GPU utilization
        
        detectFacEye(frame, conf=conf, eye_crop_size=eye_crop_size)
        cv2.imshow('Face-Detection', frame)
        
        print('Processed frame {}/{}'.format(cap.get(cv2.CAP_PROP_POS_FRAMES), total_frames))
        
        #out.write(frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    #out.release()
    cv2.destroyAllWindows()
    
    # Save the eye contact data to an Excel file
    #df = pd.DataFrame(user_eye_contact_data)
    #df.to_excel("data.xlsx", index=False)
    #print("Eye contact times saved to eye_contact_times.xlsx")

# %%
process_video('rtsp://admin:hM571632@192.168.1.64/Streaming/Channels/102', conf=0.5, eye_crop_size=10)
# Out:
# GPU utilization: 22
# Processed frame 1.0/-2562047788015215
# GPU utilization: 22
# Processed frame 2.0/-2562047788015215
# GPU utilization: 22
# Processed frame 3.0/-2562047788015215
# GPU utilization: 22
# Processed frame 4.0/-2562047788015215
# GPU utilization: 22
# Processed frame 5.0/-2562047788015215
# GPU utilization: 22
# Processed frame 6.0/-2562047788015215
# GPU utilization: 22
# Processed frame 7.0/-2562047788015215
# GPU utilization: 22
# Processed frame 8.0/-2562047788015215
# GPU utilization: 22
# Processed frame 9.0/-2562047788015215
# GPU utilization: 22
# Processed frame 10.0/-2562047788015215
# GPU utilization: 22
# Processed frame 11.0/-2562047788015215
# GPU utilization: 22
# Processed frame 12.0/-2562047788015215
# GPU utilization: 22
# Processed frame 13.0/-2562047788015215
# GPU utilization: 22
# Processed frame 14.0/-2562047788015215
# GPU utilization: 22
# Processed frame 15.0/-2562047788015215
# GPU utilization: 13
# Processed frame 16.0/-2562047788015215
# GPU utilization: 13
# Processed frame 17.0/-2562047788015215
# GPU utilization: 13
# Processed frame 18.0/-2562047788015215
# GPU utilization: 13
# Processed frame 19.0/-2562047788015215
# GPU utilization: 13
# Processed frame 20.0/-2562047788015215
# GPU utilization: 13
# Processed frame 21.0/-2562047788015215
# GPU utilization: 13
# Processed frame 22.0/-2562047788015215
# GPU utilization: 13
# Processed frame 23.0/-2562047788015215
# GPU utilization: 13
# Processed frame 24.0/-2562047788015215
# GPU utilization: 13
# Processed frame 25.0/-2562047788015215
# GPU utilization: 13
# Processed frame 26.0/-2562047788015215
# GPU utilization: 13
# Processed frame 27.0/-2562047788015215
# GPU utilization: 13
# Processed frame 28.0/-2562047788015215
# GPU utilization: 13
# Processed frame 29.0/-2562047788015215
# GPU utilization: 13
# Processed frame 30.0/-2562047788015215
# GPU utilization: 13
# Processed frame 31.0/-2562047788015215
# GPU utilization: 13
# Processed frame 32.0/-2562047788015215
# GPU utilization: 3
# Processed frame 33.0/-2562047788015215
# GPU utilization: 3
# Processed frame 34.0/-2562047788015215
# GPU utilization: 3
# Processed frame 35.0/-2562047788015215
# GPU utilization: 3
# Processed frame 36.0/-2562047788015215
# GPU utilization: 3
# Processed frame 37.0/-2562047788015215
# GPU utilization: 3
# Processed frame 38.0/-2562047788015215
# GPU utilization: 3
# Processed frame 39.0/-2562047788015215
# GPU utilization: 3
# Processed frame 40.0/-2562047788015215
# GPU utilization: 3
# Processed frame 41.0/-2562047788015215
# GPU utilization: 3
# Processed frame 42.0/-2562047788015215
# GPU utilization: 3
# Processed frame 43.0/-2562047788015215
# GPU utilization: 3
# Processed frame 44.0/-2562047788015215
# GPU utilization: 3
# Processed frame 45.0/-2562047788015215
# GPU utilization: 3
# Processed frame 46.0/-2562047788015215
# GPU utilization: 3
# Processed frame 47.0/-2562047788015215
# GPU utilization: 3
# Processed frame 48.0/-2562047788015215
# GPU utilization: 3
# Processed frame 49.0/-2562047788015215
# GPU utilization: 3
# Processed frame 50.0/-2562047788015215
# GPU utilization: 3
# Processed frame 51.0/-2562047788015215
# GPU utilization: 3
# Processed frame 52.0/-2562047788015215
# GPU utilization: 3
# Processed frame 53.0/-2562047788015215
# GPU utilization: 3
# Processed frame 54.0/-2562047788015215
# GPU utilization: 3
# Processed frame 55.0/-2562047788015215
# GPU utilization: 3
# Processed frame 56.0/-2562047788015215
# GPU utilization: 3
# Processed frame 57.0/-2562047788015215
# GPU utilization: 3
# Processed frame 58.0/-2562047788015215
# GPU utilization: 3
# Processed frame 59.0/-2562047788015215
# GPU utilization: 3
# Processed frame 60.0/-2562047788015215
# GPU utilization: 3
# Processed frame 61.0/-2562047788015215
# GPU utilization: 3
# Processed frame 62.0/-2562047788015215
# GPU utilization: 3
# Processed frame 63.0/-2562047788015215
# GPU utilization: 3
# Processed frame 64.0/-2562047788015215
# GPU utilization: 3
# Processed frame 65.0/-2562047788015215
# GPU utilization: 3
# Processed frame 66.0/-2562047788015215
# GPU utilization: 6
# Processed frame 67.0/-2562047788015215
# GPU utilization: 6
# Processed frame 68.0/-2562047788015215
# GPU utilization: 6
# Processed frame 69.0/-2562047788015215
# GPU utilization: 6
# Processed frame 70.0/-2562047788015215
# GPU utilization: 6
# Processed frame 71.0/-2562047788015215
# GPU utilization: 6
# Processed frame 72.0/-2562047788015215
# GPU utilization: 6
# Processed frame 73.0/-2562047788015215
# GPU utilization: 6
# Processed frame 74.0/-2562047788015215
# GPU utilization: 6
# Processed frame 75.0/-2562047788015215
# GPU utilization: 6
# Processed frame 76.0/-2562047788015215
# GPU utilization: 6
# Processed frame 77.0/-2562047788015215
# GPU utilization: 6
# Processed frame 78.0/-2562047788015215
# GPU utilization: 6
# Processed frame 79.0/-2562047788015215
# GPU utilization: 6
# Processed frame 80.0/-2562047788015215
# GPU utilization: 6
# Processed frame 81.0/-2562047788015215
# GPU utilization: 6
# Processed frame 82.0/-2562047788015215
# GPU utilization: 16
# Processed frame 83.0/-2562047788015215
# GPU utilization: 16
# Processed frame 84.0/-2562047788015215
# GPU utilization: 16
# Processed frame 85.0/-2562047788015215
# GPU utilization: 16
# Processed frame 86.0/-2562047788015215
# GPU utilization: 16
# Processed frame 87.0/-2562047788015215
# GPU utilization: 16
# Processed frame 88.0/-2562047788015215
# GPU utilization: 16
# Processed frame 89.0/-2562047788015215
# GPU utilization: 16
# Processed frame 90.0/-2562047788015215
# GPU utilization: 16
# Processed frame 91.0/-2562047788015215
# GPU utilization: 16
# Processed frame 92.0/-2562047788015215
# GPU utilization: 16
# Processed frame 93.0/-2562047788015215
# GPU utilization: 16
# Processed frame 94.0/-2562047788015215
# GPU utilization: 16
# Processed frame 95.0/-2562047788015215
# GPU utilization: 16
# Processed frame 96.0/-2562047788015215
# GPU utilization: 16
# Processed frame 97.0/-2562047788015215
# GPU utilization: 16
# Processed frame 98.0/-2562047788015215
# GPU utilization: 16
# Processed frame 99.0/-2562047788015215
# GPU utilization: 16
# Processed frame 100.0/-2562047788015215
# GPU utilization: 17
# Processed frame 101.0/-2562047788015215
# GPU utilization: 17
# Processed frame 102.0/-2562047788015215
# GPU utilization: 17
# Processed frame 103.0/-2562047788015215
# GPU utilization: 17
# Processed frame 104.0/-2562047788015215
# GPU utilization: 17
# Processed frame 105.0/-2562047788015215
# GPU utilization: 17
# Processed frame 106.0/-2562047788015215
# GPU utilization: 17
# Processed frame 107.0/-2562047788015215
# GPU utilization: 17
# Processed frame 108.0/-2562047788015215
# GPU utilization: 17
# Processed frame 109.0/-2562047788015215
# GPU utilization: 17
# Processed frame 110.0/-2562047788015215
# GPU utilization: 17
# Processed frame 111.0/-2562047788015215
# GPU utilization: 17
# Processed frame 112.0/-2562047788015215
# GPU utilization: 17
# Processed frame 113.0/-2562047788015215
# GPU utilization: 17
# Processed frame 114.0/-2562047788015215
# GPU utilization: 17
# Processed frame 115.0/-2562047788015215
# GPU utilization: 17
# Processed frame 116.0/-2562047788015215
# GPU utilization: 17
# Processed frame 117.0/-2562047788015215
# GPU utilization: 18
# Processed frame 118.0/-2562047788015215
# GPU utilization: 18
# Processed frame 119.0/-2562047788015215
# GPU utilization: 18
# Processed frame 120.0/-2562047788015215
# GPU utilization: 18
# Processed frame 121.0/-2562047788015215
# GPU utilization: 18
# Processed frame 122.0/-2562047788015215
# GPU utilization: 18
# Processed frame 123.0/-2562047788015215
# GPU utilization: 18
# Processed frame 124.0/-2562047788015215
# GPU utilization: 18
# Processed frame 125.0/-2562047788015215
# GPU utilization: 18
# Processed frame 126.0/-2562047788015215
# GPU utilization: 18
# Processed frame 127.0/-2562047788015215
# GPU utilization: 18
# Processed frame 128.0/-2562047788015215
# GPU utilization: 18
# Processed frame 129.0/-2562047788015215
# GPU utilization: 18
# Processed frame 130.0/-2562047788015215
# GPU utilization: 18
# Processed frame 131.0/-2562047788015215
# GPU utilization: 18
# Processed frame 132.0/-2562047788015215
# GPU utilization: 18
# Processed frame 133.0/-2562047788015215
# GPU utilization: 18
# Processed frame 134.0/-2562047788015215
# GPU utilization: 14
# Processed frame 135.0/-2562047788015215
# GPU utilization: 14
# Processed frame 136.0/-2562047788015215
# GPU utilization: 14
# Processed frame 137.0/-2562047788015215
# GPU utilization: 14
# Processed frame 138.0/-2562047788015215
# GPU utilization: 14
# Processed frame 139.0/-2562047788015215
# GPU utilization: 14
# Processed frame 140.0/-2562047788015215
# GPU utilization: 14
# Processed frame 141.0/-2562047788015215
# GPU utilization: 14
# Processed frame 142.0/-2562047788015215
# GPU utilization: 14
# Processed frame 143.0/-2562047788015215
# GPU utilization: 14
# Processed frame 144.0/-2562047788015215
# GPU utilization: 14
# Processed frame 145.0/-2562047788015215
# GPU utilization: 14
# Processed frame 146.0/-2562047788015215
# GPU utilization: 14
# Processed frame 147.0/-2562047788015215
# GPU utilization: 14
# Processed frame 148.0/-2562047788015215
# GPU utilization: 14
# Processed frame 149.0/-2562047788015215
# GPU utilization: 15
# Processed frame 150.0/-2562047788015215
# GPU utilization: 15
# Processed frame 151.0/-2562047788015215
# GPU utilization: 15
# Processed frame 152.0/-2562047788015215
# GPU utilization: 15
# Processed frame 153.0/-2562047788015215
# GPU utilization: 15
# Processed frame 154.0/-2562047788015215
# GPU utilization: 15
# Processed frame 155.0/-2562047788015215
# GPU utilization: 15
# Processed frame 156.0/-2562047788015215
# GPU utilization: 15
# Processed frame 157.0/-2562047788015215
# GPU utilization: 15
# Processed frame 158.0/-2562047788015215
# GPU utilization: 15
# Processed frame 159.0/-2562047788015215
# GPU utilization: 15
# Processed frame 160.0/-2562047788015215
# GPU utilization: 15
# Processed frame 161.0/-2562047788015215
# GPU utilization: 15
# Processed frame 162.0/-2562047788015215
# GPU utilization: 15
# Processed frame 163.0/-2562047788015215
# GPU utilization: 15
# Processed frame 164.0/-2562047788015215
# GPU utilization: 15
# Processed frame 165.0/-2562047788015215
# GPU utilization: 15
# Processed frame 166.0/-2562047788015215
# GPU utilization: 15
# Processed frame 167.0/-2562047788015215
# GPU utilization: 15
# Processed frame 168.0/-2562047788015215
# GPU utilization: 17
# Processed frame 169.0/-2562047788015215
# GPU utilization: 17
# Processed frame 170.0/-2562047788015215
# GPU utilization: 17
# Processed frame 171.0/-2562047788015215
# GPU utilization: 17
# Processed frame 172.0/-2562047788015215
# GPU utilization: 17
# Processed frame 173.0/-2562047788015215
# GPU utilization: 17
# Processed frame 174.0/-2562047788015215
# GPU utilization: 17
# Processed frame 175.0/-2562047788015215
# GPU utilization: 17
# Processed frame 176.0/-2562047788015215
# GPU utilization: 17
# Processed frame 177.0/-2562047788015215
# GPU utilization: 17
# Processed frame 178.0/-2562047788015215
# GPU utilization: 17
# Processed frame 179.0/-2562047788015215
# GPU utilization: 17
# Processed frame 180.0/-2562047788015215
# GPU utilization: 17
# Processed frame 181.0/-2562047788015215
# GPU utilization: 17
# Processed frame 182.0/-2562047788015215
# GPU utilization: 17
# Processed frame 183.0/-2562047788015215
# GPU utilization: 17
# Processed frame 184.0/-2562047788015215
# GPU utilization: 17
# Processed frame 185.0/-2562047788015215
# GPU utilization: 17
# Processed frame 186.0/-2562047788015215
# GPU utilization: 17
# Processed frame 187.0/-2562047788015215
# GPU utilization: 17
# Processed frame 188.0/-2562047788015215
# GPU utilization: 17
# Processed frame 189.0/-2562047788015215
# GPU utilization: 17
# Processed frame 190.0/-2562047788015215
# GPU utilization: 17
# Processed frame 191.0/-2562047788015215
# GPU utilization: 17
# Processed frame 192.0/-2562047788015215
# GPU utilization: 17
# Processed frame 193.0/-2562047788015215
# GPU utilization: 17
# Processed frame 194.0/-2562047788015215
# GPU utilization: 17
# Processed frame 195.0/-2562047788015215
# GPU utilization: 17
# Processed frame 196.0/-2562047788015215
# GPU utilization: 17
# Processed frame 197.0/-2562047788015215
# GPU utilization: 17
# Processed frame 198.0/-2562047788015215
# GPU utilization: 17
# Processed frame 199.0/-2562047788015215
# GPU utilization: 17
# Processed frame 200.0/-2562047788015215
# GPU utilization: 17
# Processed frame 201.0/-2562047788015215
# GPU utilization: 17
# Processed frame 202.0/-2562047788015215
# GPU utilization: 17
# Processed frame 203.0/-2562047788015215
# GPU utilization: 17
# Processed frame 204.0/-2562047788015215
# GPU utilization: 13
# Processed frame 205.0/-2562047788015215
# GPU utilization: 13
# Processed frame 206.0/-2562047788015215
# GPU utilization: 13
# Processed frame 207.0/-2562047788015215
# GPU utilization: 13
# Processed frame 208.0/-2562047788015215
# GPU utilization: 13
# Processed frame 209.0/-2562047788015215
# GPU utilization: 13
# Processed frame 210.0/-2562047788015215
# GPU utilization: 13
# Processed frame 211.0/-2562047788015215
# GPU utilization: 13
# Processed frame 212.0/-2562047788015215
# GPU utilization: 13
# Processed frame 213.0/-2562047788015215
# GPU utilization: 13
# Processed frame 214.0/-2562047788015215
# GPU utilization: 13
# Processed frame 215.0/-2562047788015215
# GPU utilization: 13
# Processed frame 216.0/-2562047788015215
# GPU utilization: 17
# Processed frame 217.0/-2562047788015215
# GPU utilization: 11
# Processed frame 218.0/-2562047788015215
# GPU utilization: 11
# Processed frame 219.0/-2562047788015215
# GPU utilization: 11
# Processed frame 220.0/-2562047788015215
# GPU utilization: 11
# Processed frame 221.0/-2562047788015215
# GPU utilization: 11
# Processed frame 222.0/-2562047788015215
# GPU utilization: 11
# Processed frame 223.0/-2562047788015215
# GPU utilization: 11
# Processed frame 224.0/-2562047788015215
# GPU utilization: 11
# Processed frame 225.0/-2562047788015215
# GPU utilization: 11
# Processed frame 226.0/-2562047788015215
# GPU utilization: 11
# Processed frame 227.0/-2562047788015215
# GPU utilization: 11
# Processed frame 228.0/-2562047788015215
# GPU utilization: 11
# Processed frame 229.0/-2562047788015215
# GPU utilization: 11
# Processed frame 230.0/-2562047788015215
# GPU utilization: 11
# Processed frame 231.0/-2562047788015215
# GPU utilization: 11
# Processed frame 232.0/-2562047788015215
# GPU utilization: 11
# Processed frame 233.0/-2562047788015215
# GPU utilization: 16
# Processed frame 234.0/-2562047788015215
# GPU utilization: 16
# Processed frame 235.0/-2562047788015215
# GPU utilization: 16
# Processed frame 236.0/-2562047788015215
# GPU utilization: 16
# Processed frame 237.0/-2562047788015215
# GPU utilization: 16
# Processed frame 238.0/-2562047788015215
# GPU utilization: 16
# Processed frame 239.0/-2562047788015215
# GPU utilization: 16
# Processed frame 240.0/-2562047788015215
# GPU utilization: 16
# Processed frame 241.0/-2562047788015215
# GPU utilization: 16
# Processed frame 242.0/-2562047788015215
# GPU utilization: 16
# Processed frame 243.0/-2562047788015215
# GPU utilization: 16
# Processed frame 244.0/-2562047788015215
# GPU utilization: 16
# Processed frame 245.0/-2562047788015215
# GPU utilization: 16
# Processed frame 246.0/-2562047788015215
# GPU utilization: 16
# Processed frame 247.0/-2562047788015215
# GPU utilization: 16
# Processed frame 248.0/-2562047788015215
# GPU utilization: 16
# Processed frame 249.0/-2562047788015215
# GPU utilization: 16
# Processed frame 250.0/-2562047788015215
# GPU utilization: 19
# Processed frame 251.0/-2562047788015215
# GPU utilization: 19
# Processed frame 252.0/-2562047788015215
# GPU utilization: 19
# Processed frame 253.0/-2562047788015215
# GPU utilization: 19
# Processed frame 254.0/-2562047788015215
# GPU utilization: 19
# Processed frame 255.0/-2562047788015215
# GPU utilization: 19
# Processed frame 256.0/-2562047788015215
# GPU utilization: 19
# Processed frame 257.0/-2562047788015215
# GPU utilization: 19
# Processed frame 258.0/-2562047788015215
# GPU utilization: 19
# Processed frame 259.0/-2562047788015215
# GPU utilization: 19
# Processed frame 260.0/-2562047788015215
# GPU utilization: 19
# Processed frame 261.0/-2562047788015215
# GPU utilization: 19
# Processed frame 262.0/-2562047788015215
# GPU utilization: 19
# Processed frame 263.0/-2562047788015215
# GPU utilization: 19
# Processed frame 264.0/-2562047788015215
# GPU utilization: 19
# Processed frame 265.0/-2562047788015215
# GPU utilization: 19
# Processed frame 266.0/-2562047788015215
# GPU utilization: 19
# Processed frame 267.0/-2562047788015215
# GPU utilization: 19
# Processed frame 268.0/-2562047788015215
# GPU utilization: 21
# Processed frame 269.0/-2562047788015215
# GPU utilization: 21
# Processed frame 270.0/-2562047788015215
# GPU utilization: 21
# Processed frame 271.0/-2562047788015215
# GPU utilization: 21
# Processed frame 272.0/-2562047788015215
# GPU utilization: 21
# Processed frame 273.0/-2562047788015215
# GPU utilization: 21
# Processed frame 274.0/-2562047788015215
# GPU utilization: 21
# Processed frame 275.0/-2562047788015215
# GPU utilization: 21
# Processed frame 276.0/-2562047788015215
# GPU utilization: 21
# Processed frame 277.0/-2562047788015215
# GPU utilization: 21
# Processed frame 278.0/-2562047788015215
# GPU utilization: 21
# Processed frame 279.0/-2562047788015215
# GPU utilization: 21
# Processed frame 280.0/-2562047788015215
# GPU utilization: 21
# Processed frame 281.0/-2562047788015215
# GPU utilization: 21
# Processed frame 282.0/-2562047788015215
# GPU utilization: 21
# Processed frame 283.0/-2562047788015215
# GPU utilization: 21
# Processed frame 284.0/-2562047788015215
# GPU utilization: 12
# Processed frame 285.0/-2562047788015215
# GPU utilization: 12
# Processed frame 286.0/-2562047788015215
# GPU utilization: 12
# Processed frame 287.0/-2562047788015215
# GPU utilization: 12
# Processed frame 288.0/-2562047788015215
# GPU utilization: 12
# Processed frame 289.0/-2562047788015215
# GPU utilization: 12
# Processed frame 290.0/-2562047788015215
# GPU utilization: 12
# Processed frame 291.0/-2562047788015215
# GPU utilization: 12
# Processed frame 292.0/-2562047788015215
# GPU utilization: 12
# Processed frame 293.0/-2562047788015215
# GPU utilization: 12
# Processed frame 294.0/-2562047788015215
# GPU utilization: 12
# Processed frame 295.0/-2562047788015215
# GPU utilization: 12
# Processed frame 296.0/-2562047788015215
# GPU utilization: 12
# Processed frame 297.0/-2562047788015215
# GPU utilization: 12
# Processed frame 298.0/-2562047788015215
# GPU utilization: 12
# Processed frame 299.0/-2562047788015215
# GPU utilization: 12
# Processed frame 300.0/-2562047788015215
# GPU utilization: 17
# Processed frame 301.0/-2562047788015215
# GPU utilization: 17
# Processed frame 302.0/-2562047788015215
# GPU utilization: 17
# Processed frame 303.0/-2562047788015215
# GPU utilization: 17
# Processed frame 304.0/-2562047788015215
# GPU utilization: 17
# Processed frame 305.0/-2562047788015215
# GPU utilization: 17
# Processed frame 306.0/-2562047788015215
# GPU utilization: 17
# Processed frame 307.0/-2562047788015215
# GPU utilization: 17
# Processed frame 308.0/-2562047788015215
# GPU utilization: 17
# Processed frame 309.0/-2562047788015215
# GPU utilization: 17
# Processed frame 310.0/-2562047788015215
# GPU utilization: 17
# Processed frame 311.0/-2562047788015215
# GPU utilization: 17
# Processed frame 312.0/-2562047788015215
# GPU utilization: 17
# Processed frame 313.0/-2562047788015215
# GPU utilization: 17
# Processed frame 314.0/-2562047788015215
# GPU utilization: 17
# Processed frame 315.0/-2562047788015215
# GPU utilization: 17
# Processed frame 316.0/-2562047788015215
# GPU utilization: 27
# Processed frame 317.0/-2562047788015215
# GPU utilization: 27
# Processed frame 318.0/-2562047788015215
# GPU utilization: 27
# Processed frame 319.0/-2562047788015215
# GPU utilization: 27
# Processed frame 320.0/-2562047788015215
# GPU utilization: 27
# Processed frame 321.0/-2562047788015215
# GPU utilization: 27
# Processed frame 322.0/-2562047788015215
# GPU utilization: 27
# Processed frame 323.0/-2562047788015215
# GPU utilization: 27
# Processed frame 324.0/-2562047788015215
# GPU utilization: 27
# Processed frame 325.0/-2562047788015215
# GPU utilization: 27
# Processed frame 326.0/-2562047788015215
# GPU utilization: 27
# Processed frame 327.0/-2562047788015215
# GPU utilization: 27
# Processed frame 328.0/-2562047788015215
# GPU utilization: 27
# Processed frame 329.0/-2562047788015215
# GPU utilization: 27
# Processed frame 330.0/-2562047788015215
# GPU utilization: 27
# Processed frame 331.0/-2562047788015215
# GPU utilization: 22
# Processed frame 332.0/-2562047788015215
# GPU utilization: 22
# Processed frame 333.0/-2562047788015215
# GPU utilization: 22
# Processed frame 334.0/-2562047788015215
# GPU utilization: 22
# Processed frame 335.0/-2562047788015215
# GPU utilization: 22
# Processed frame 336.0/-2562047788015215
# GPU utilization: 22
# Processed frame 337.0/-2562047788015215
# GPU utilization: 22
# Processed frame 338.0/-2562047788015215
# GPU utilization: 22
# Processed frame 339.0/-2562047788015215
# GPU utilization: 22
# Processed frame 340.0/-2562047788015215
# GPU utilization: 22
# Processed frame 341.0/-2562047788015215
# GPU utilization: 22
# Processed frame 342.0/-2562047788015215
# GPU utilization: 22
# Processed frame 343.0/-2562047788015215
# GPU utilization: 22
# Processed frame 344.0/-2562047788015215
# GPU utilization: 22
# Processed frame 345.0/-2562047788015215
# GPU utilization: 22
# Processed frame 346.0/-2562047788015215
# GPU utilization: 22
# Processed frame 347.0/-2562047788015215
# GPU utilization: 22
# Processed frame 348.0/-2562047788015215
# GPU utilization: 22
# Processed frame 349.0/-2562047788015215
# GPU utilization: 14
# Processed frame 350.0/-2562047788015215
# GPU utilization: 14
# Processed frame 351.0/-2562047788015215
# GPU utilization: 14
# Processed frame 352.0/-2562047788015215
# GPU utilization: 14
# Processed frame 353.0/-2562047788015215
# GPU utilization: 14
# Processed frame 354.0/-2562047788015215
# GPU utilization: 14
# Processed frame 355.0/-2562047788015215
# GPU utilization: 14
# Processed frame 356.0/-2562047788015215
# GPU utilization: 14
# Processed frame 357.0/-2562047788015215
# GPU utilization: 14
# Processed frame 358.0/-2562047788015215
# GPU utilization: 14
# Processed frame 359.0/-2562047788015215
# GPU utilization: 14
# Processed frame 360.0/-2562047788015215
# GPU utilization: 14
# Processed frame 361.0/-2562047788015215
# GPU utilization: 14
# Processed frame 362.0/-2562047788015215
# GPU utilization: 14
# Processed frame 363.0/-2562047788015215
# GPU utilization: 14
# Processed frame 364.0/-2562047788015215
# GPU utilization: 21
# Processed frame 365.0/-2562047788015215
# GPU utilization: 21
# Processed frame 366.0/-2562047788015215
# GPU utilization: 21
# Processed frame 367.0/-2562047788015215
# GPU utilization: 21
# Processed frame 368.0/-2562047788015215
# GPU utilization: 21
# Processed frame 369.0/-2562047788015215
# GPU utilization: 21
# Processed frame 370.0/-2562047788015215
# GPU utilization: 21
# Processed frame 371.0/-2562047788015215
# GPU utilization: 21
# Processed frame 372.0/-2562047788015215
# GPU utilization: 21
# Processed frame 373.0/-2562047788015215
# GPU utilization: 21
# Processed frame 374.0/-2562047788015215
# GPU utilization: 21
# Processed frame 375.0/-2562047788015215
# GPU utilization: 21
# Processed frame 376.0/-2562047788015215
# GPU utilization: 21
# Processed frame 377.0/-2562047788015215
# GPU utilization: 21
# Processed frame 378.0/-2562047788015215
# GPU utilization: 21
# Processed frame 379.0/-2562047788015215
# GPU utilization: 21
# Processed frame 380.0/-2562047788015215
# GPU utilization: 21
# Processed frame 381.0/-2562047788015215
# GPU utilization: 21
# Processed frame 382.0/-2562047788015215
# GPU utilization: 17
# Processed frame 383.0/-2562047788015215
# GPU utilization: 17
# Processed frame 384.0/-2562047788015215
# GPU utilization: 17
# Processed frame 385.0/-2562047788015215
# GPU utilization: 17
# Processed frame 386.0/-2562047788015215
# GPU utilization: 17
# Processed frame 387.0/-2562047788015215
# GPU utilization: 17
# Processed frame 388.0/-2562047788015215
# GPU utilization: 17
# Processed frame 389.0/-2562047788015215
# GPU utilization: 17
# Processed frame 390.0/-2562047788015215
# GPU utilization: 17
# Processed frame 391.0/-2562047788015215
# GPU utilization: 17
# Processed frame 392.0/-2562047788015215
# GPU utilization: 17
# Processed frame 393.0/-2562047788015215
# GPU utilization: 17
# Processed frame 394.0/-2562047788015215
# GPU utilization: 17
# Processed frame 395.0/-2562047788015215
# GPU utilization: 17
# Processed frame 396.0/-2562047788015215
# GPU utilization: 17
# Processed frame 397.0/-2562047788015215
# GPU utilization: 17
# Processed frame 398.0/-2562047788015215
# GPU utilization: 17
# Processed frame 399.0/-2562047788015215
# GPU utilization: 17
# Processed frame 400.0/-2562047788015215
# GPU utilization: 20
# Processed frame 401.0/-2562047788015215
# GPU utilization: 20
# Processed frame 402.0/-2562047788015215
# GPU utilization: 20
# Processed frame 403.0/-2562047788015215
# GPU utilization: 20
# Processed frame 404.0/-2562047788015215
# GPU utilization: 20
# Processed frame 405.0/-2562047788015215
# GPU utilization: 20
# Processed frame 406.0/-2562047788015215
# GPU utilization: 20
# Processed frame 407.0/-2562047788015215
# GPU utilization: 20
# Processed frame 408.0/-2562047788015215
# GPU utilization: 20
# Processed frame 409.0/-2562047788015215
# GPU utilization: 20
# Processed frame 410.0/-2562047788015215
# GPU utilization: 20
# Processed frame 411.0/-2562047788015215
# GPU utilization: 20
# Processed frame 412.0/-2562047788015215
# GPU utilization: 20
# Processed frame 413.0/-2562047788015215
# GPU utilization: 20
# Processed frame 414.0/-2562047788015215
# GPU utilization: 20
# Processed frame 415.0/-2562047788015215
# GPU utilization: 20
# Processed frame 416.0/-2562047788015215
# GPU utilization: 20
# Processed frame 417.0/-2562047788015215
# GPU utilization: 16
# Processed frame 418.0/-2562047788015215
# GPU utilization: 16
# Processed frame 419.0/-2562047788015215
# GPU utilization: 16
# Processed frame 420.0/-2562047788015215
# GPU utilization: 16
# Processed frame 421.0/-2562047788015215
# GPU utilization: 16
# Processed frame 422.0/-2562047788015215
# GPU utilization: 16
# Processed frame 423.0/-2562047788015215
# GPU utilization: 16
# Processed frame 424.0/-2562047788015215
# GPU utilization: 16
# Processed frame 425.0/-2562047788015215
# GPU utilization: 16
# Processed frame 426.0/-2562047788015215
# GPU utilization: 16
# Processed frame 427.0/-2562047788015215
# GPU utilization: 16
# Processed frame 428.0/-2562047788015215
# GPU utilization: 16
# Processed frame 429.0/-2562047788015215
# GPU utilization: 16
# Processed frame 430.0/-2562047788015215
# GPU utilization: 16
# Processed frame 431.0/-2562047788015215
# GPU utilization: 16
# Processed frame 432.0/-2562047788015215
# GPU utilization: 16
# Processed frame 433.0/-2562047788015215
# GPU utilization: 16
# Processed frame 434.0/-2562047788015215
# GPU utilization: 16
# Processed frame 435.0/-2562047788015215
# GPU utilization: 16
# Processed frame 436.0/-2562047788015215
# GPU utilization: 16
# Processed frame 437.0/-2562047788015215
# GPU utilization: 16
# Processed frame 438.0/-2562047788015215
# GPU utilization: 16
# Processed frame 439.0/-2562047788015215
# GPU utilization: 16
# Processed frame 440.0/-2562047788015215
# GPU utilization: 16
# Processed frame 441.0/-2562047788015215
# GPU utilization: 16
# Processed frame 442.0/-2562047788015215
# GPU utilization: 16
# Processed frame 443.0/-2562047788015215
# GPU utilization: 16
# Processed frame 444.0/-2562047788015215
# GPU utilization: 16
# Processed frame 445.0/-2562047788015215
# GPU utilization: 16
# Processed frame 446.0/-2562047788015215
# GPU utilization: 16
# Processed frame 447.0/-2562047788015215
# GPU utilization: 16
# Processed frame 448.0/-2562047788015215
# GPU utilization: 16
# Processed frame 449.0/-2562047788015215
# GPU utilization: 16
# Processed frame 450.0/-2562047788015215
# GPU utilization: 16
# Processed frame 451.0/-2562047788015215
# GPU utilization: 16
# Processed frame 452.0/-2562047788015215
# GPU utilization: 17
# Processed frame 453.0/-2562047788015215
# GPU utilization: 17
# Processed frame 454.0/-2562047788015215
# GPU utilization: 17
# Processed frame 455.0/-2562047788015215
# GPU utilization: 17
# Processed frame 456.0/-2562047788015215
# GPU utilization: 17
# Processed frame 457.0/-2562047788015215
# GPU utilization: 17
# Processed frame 458.0/-2562047788015215
# GPU utilization: 17
# Processed frame 459.0/-2562047788015215
# GPU utilization: 17
# Processed frame 460.0/-2562047788015215
# GPU utilization: 17
# Processed frame 461.0/-2562047788015215
# GPU utilization: 17
# Processed frame 462.0/-2562047788015215
# GPU utilization: 17
# Processed frame 463.0/-2562047788015215
# GPU utilization: 17
# Processed frame 464.0/-2562047788015215
# GPU utilization: 17
# Processed frame 465.0/-2562047788015215
# GPU utilization: 17
# Processed frame 466.0/-2562047788015215
# GPU utilization: 17
# Processed frame 467.0/-2562047788015215
# GPU utilization: 17
# Processed frame 468.0/-2562047788015215
# GPU utilization: 17
# Processed frame 469.0/-2562047788015215
# GPU utilization: 15
# Processed frame 470.0/-2562047788015215
# GPU utilization: 15
# Processed frame 471.0/-2562047788015215
# GPU utilization: 15
# Processed frame 472.0/-2562047788015215
# GPU utilization: 15
# Processed frame 473.0/-2562047788015215
# GPU utilization: 15
# Processed frame 474.0/-2562047788015215
# GPU utilization: 15
# Processed frame 475.0/-2562047788015215
# GPU utilization: 15
# Processed frame 476.0/-2562047788015215
# GPU utilization: 15
# Processed frame 477.0/-2562047788015215
# GPU utilization: 15
# Processed frame 478.0/-2562047788015215
# GPU utilization: 15
# Processed frame 479.0/-2562047788015215
# GPU utilization: 15
# Processed frame 480.0/-2562047788015215
# GPU utilization: 15
# Processed frame 481.0/-2562047788015215
# GPU utilization: 15
# Processed frame 482.0/-2562047788015215
# GPU utilization: 15
# Processed frame 483.0/-2562047788015215
# GPU utilization: 15
# Processed frame 484.0/-2562047788015215
# GPU utilization: 15
# Processed frame 485.0/-2562047788015215
# GPU utilization: 15
# Processed frame 486.0/-2562047788015215
# GPU utilization: 15
# Processed frame 487.0/-2562047788015215
# GPU utilization: 13
# Processed frame 488.0/-2562047788015215
# GPU utilization: 13
# Processed frame 489.0/-2562047788015215
# GPU utilization: 13
# Processed frame 490.0/-2562047788015215
# GPU utilization: 13
# Processed frame 491.0/-2562047788015215
# GPU utilization: 13
# Processed frame 492.0/-2562047788015215
# GPU utilization: 13
# Processed frame 493.0/-2562047788015215
# GPU utilization: 13
# Processed frame 494.0/-2562047788015215
# GPU utilization: 13
# Processed frame 495.0/-2562047788015215
# GPU utilization: 13
# Processed frame 496.0/-2562047788015215
# GPU utilization: 13
# Processed frame 497.0/-2562047788015215
# GPU utilization: 13
# Processed frame 498.0/-2562047788015215
# GPU utilization: 13
# Processed frame 499.0/-2562047788015215
# GPU utilization: 13
# Processed frame 500.0/-2562047788015215
# GPU utilization: 13
# Processed frame 501.0/-2562047788015215
# GPU utilization: 13
# Processed frame 502.0/-2562047788015215
# GPU utilization: 13
# Processed frame 503.0/-2562047788015215
# GPU utilization: 13
# Processed frame 504.0/-2562047788015215
# GPU utilization: 19
# Processed frame 505.0/-2562047788015215
# GPU utilization: 19
# Processed frame 506.0/-2562047788015215
# GPU utilization: 19
# Processed frame 507.0/-2562047788015215
# GPU utilization: 19
# Processed frame 508.0/-2562047788015215
# GPU utilization: 19
# Processed frame 509.0/-2562047788015215
# GPU utilization: 19
# Processed frame 510.0/-2562047788015215
# GPU utilization: 19
# Processed frame 511.0/-2562047788015215
# GPU utilization: 19
# Processed frame 512.0/-2562047788015215
# GPU utilization: 19
# Processed frame 513.0/-2562047788015215
# GPU utilization: 19
# Processed frame 514.0/-2562047788015215
# GPU utilization: 19
# Processed frame 515.0/-2562047788015215
# GPU utilization: 19
# Processed frame 516.0/-2562047788015215
# GPU utilization: 19
# Processed frame 517.0/-2562047788015215
# GPU utilization: 19
# Processed frame 518.0/-2562047788015215
# GPU utilization: 19
# Processed frame 519.0/-2562047788015215
# GPU utilization: 19
# Processed frame 520.0/-2562047788015215
# GPU utilization: 19
# Processed frame 521.0/-2562047788015215
# GPU utilization: 19
# Processed frame 522.0/-2562047788015215
# GPU utilization: 19
# Processed frame 523.0/-2562047788015215
# GPU utilization: 19
# Processed frame 524.0/-2562047788015215
# GPU utilization: 19
# Processed frame 525.0/-2562047788015215
# GPU utilization: 19
# Processed frame 526.0/-2562047788015215
# GPU utilization: 19
# Processed frame 527.0/-2562047788015215
# GPU utilization: 19
# Processed frame 528.0/-2562047788015215
# GPU utilization: 19
# Processed frame 529.0/-2562047788015215
# GPU utilization: 19
# Processed frame 530.0/-2562047788015215
# GPU utilization: 19
# Processed frame 531.0/-2562047788015215
# GPU utilization: 19
# Processed frame 532.0/-2562047788015215
# GPU utilization: 19
# Processed frame 533.0/-2562047788015215
# GPU utilization: 19
# Processed frame 534.0/-2562047788015215
# GPU utilization: 19
# Processed frame 535.0/-2562047788015215
# GPU utilization: 19
# Processed frame 536.0/-2562047788015215
# GPU utilization: 15
# Processed frame 537.0/-2562047788015215
# GPU utilization: 15
# Processed frame 538.0/-2562047788015215
# GPU utilization: 15
# Processed frame 539.0/-2562047788015215
# GPU utilization: 15
# Processed frame 540.0/-2562047788015215
# GPU utilization: 15
# Processed frame 541.0/-2562047788015215
# GPU utilization: 15
# Processed frame 542.0/-2562047788015215
# GPU utilization: 15
# Processed frame 543.0/-2562047788015215
# GPU utilization: 15
# Processed frame 544.0/-2562047788015215
# GPU utilization: 15
# Processed frame 545.0/-2562047788015215
# GPU utilization: 15
# Processed frame 546.0/-2562047788015215
# GPU utilization: 15
# Processed frame 547.0/-2562047788015215
# GPU utilization: 15
# Processed frame 548.0/-2562047788015215
# GPU utilization: 15
# Processed frame 549.0/-2562047788015215
# GPU utilization: 15
# Processed frame 550.0/-2562047788015215
# GPU utilization: 15
# Processed frame 551.0/-2562047788015215
# GPU utilization: 15
# Processed frame 552.0/-2562047788015215
# GPU utilization: 15
# Processed frame 553.0/-2562047788015215
# GPU utilization: 15
# Processed frame 554.0/-2562047788015215
# GPU utilization: 15
# Processed frame 555.0/-2562047788015215
# GPU utilization: 16
# Processed frame 556.0/-2562047788015215
# GPU utilization: 16
# Processed frame 557.0/-2562047788015215
# GPU utilization: 16
# Processed frame 558.0/-2562047788015215
# GPU utilization: 16
# Processed frame 559.0/-2562047788015215
# GPU utilization: 16
# Processed frame 560.0/-2562047788015215
# GPU utilization: 16
# Processed frame 561.0/-2562047788015215
# GPU utilization: 16
# Processed frame 562.0/-2562047788015215
# GPU utilization: 16
# Processed frame 563.0/-2562047788015215
# GPU utilization: 16
# Processed frame 564.0/-2562047788015215
# GPU utilization: 16
# Processed frame 565.0/-2562047788015215
# GPU utilization: 16
# Processed frame 566.0/-2562047788015215
# GPU utilization: 16
# Processed frame 567.0/-2562047788015215
# GPU utilization: 16
# Processed frame 568.0/-2562047788015215
# GPU utilization: 16
# Processed frame 569.0/-2562047788015215
# GPU utilization: 16
# Processed frame 570.0/-2562047788015215
# GPU utilization: 16
# Processed frame 571.0/-2562047788015215
# GPU utilization: 15
# Processed frame 572.0/-2562047788015215
# GPU utilization: 15
# Processed frame 573.0/-2562047788015215
# GPU utilization: 15
# Processed frame 574.0/-2562047788015215
# GPU utilization: 15
# Processed frame 575.0/-2562047788015215
# GPU utilization: 15
# Processed frame 576.0/-2562047788015215
# GPU utilization: 15
# Processed frame 577.0/-2562047788015215
# GPU utilization: 15
# Processed frame 578.0/-2562047788015215
# GPU utilization: 15
# Processed frame 579.0/-2562047788015215
# GPU utilization: 15
# Processed frame 580.0/-2562047788015215
# GPU utilization: 15
# Processed frame 581.0/-2562047788015215
# GPU utilization: 15
# Processed frame 582.0/-2562047788015215
# GPU utilization: 15
# Processed frame 583.0/-2562047788015215
# GPU utilization: 15
# Processed frame 584.0/-2562047788015215
# GPU utilization: 15
# Processed frame 585.0/-2562047788015215
# GPU utilization: 15
# Processed frame 586.0/-2562047788015215
# GPU utilization: 15
# Processed frame 587.0/-2562047788015215
# GPU utilization: 15
# Processed frame 588.0/-2562047788015215
# GPU utilization: 16
# Processed frame 589.0/-2562047788015215
# GPU utilization: 16
# Processed frame 590.0/-2562047788015215
# GPU utilization: 16
# Processed frame 591.0/-2562047788015215
# GPU utilization: 16
# Processed frame 592.0/-2562047788015215
# GPU utilization: 16
# Processed frame 593.0/-2562047788015215
# GPU utilization: 16
# Processed frame 594.0/-2562047788015215
# GPU utilization: 16
# Processed frame 595.0/-2562047788015215
# GPU utilization: 16
# Processed frame 596.0/-2562047788015215
# GPU utilization: 16
# Processed frame 597.0/-2562047788015215
# GPU utilization: 16
# Processed frame 598.0/-2562047788015215
# GPU utilization: 16
# Processed frame 599.0/-2562047788015215
# GPU utilization: 16
# Processed frame 600.0/-2562047788015215
# GPU utilization: 16
# Processed frame 601.0/-2562047788015215
# GPU utilization: 16
# Processed frame 602.0/-2562047788015215
# GPU utilization: 16
# Processed frame 603.0/-2562047788015215
# GPU utilization: 16
# Processed frame 604.0/-2562047788015215
# GPU utilization: 14
# Processed frame 605.0/-2562047788015215
# GPU utilization: 14
# Processed frame 606.0/-2562047788015215
# GPU utilization: 14
# Processed frame 607.0/-2562047788015215
# GPU utilization: 14
# Processed frame 608.0/-2562047788015215
# GPU utilization: 14
# Processed frame 609.0/-2562047788015215
# GPU utilization: 14
# Processed frame 610.0/-2562047788015215
# GPU utilization: 14
# Processed frame 611.0/-2562047788015215
# GPU utilization: 14
# Processed frame 612.0/-2562047788015215
# GPU utilization: 14
# Processed frame 613.0/-2562047788015215
# GPU utilization: 14
# Processed frame 614.0/-2562047788015215
# GPU utilization: 14
# Processed frame 615.0/-2562047788015215
# GPU utilization: 14
# Processed frame 616.0/-2562047788015215
# GPU utilization: 14
# Processed frame 617.0/-2562047788015215
# GPU utilization: 14
# Processed frame 618.0/-2562047788015215
# GPU utilization: 14
# Processed frame 619.0/-2562047788015215
# GPU utilization: 14
# Processed frame 620.0/-2562047788015215
# GPU utilization: 14
# Processed frame 621.0/-2562047788015215
# GPU utilization: 14
# Processed frame 622.0/-2562047788015215
# GPU utilization: 14
# Processed frame 623.0/-2562047788015215
# GPU utilization: 14
# Processed frame 624.0/-2562047788015215
# GPU utilization: 14
# Processed frame 625.0/-2562047788015215
# GPU utilization: 14
# Processed frame 626.0/-2562047788015215
# GPU utilization: 14
# Processed frame 627.0/-2562047788015215
# GPU utilization: 14
# Processed frame 628.0/-2562047788015215
# GPU utilization: 14
# Processed frame 629.0/-2562047788015215
# GPU utilization: 14
# Processed frame 630.0/-2562047788015215
# GPU utilization: 14
# Processed frame 631.0/-2562047788015215
# GPU utilization: 14
# Processed frame 632.0/-2562047788015215
# GPU utilization: 14
# Processed frame 633.0/-2562047788015215
# GPU utilization: 14
# Processed frame 634.0/-2562047788015215
# GPU utilization: 14
# Processed frame 635.0/-2562047788015215
# GPU utilization: 14
# Processed frame 636.0/-2562047788015215
# GPU utilization: 14
# Processed frame 637.0/-2562047788015215
# GPU utilization: 15
# Processed frame 638.0/-2562047788015215
# GPU utilization: 15
# Processed frame 639.0/-2562047788015215
# GPU utilization: 15
# Processed frame 640.0/-2562047788015215
# GPU utilization: 15
# Processed frame 641.0/-2562047788015215
# GPU utilization: 15
# Processed frame 642.0/-2562047788015215
# GPU utilization: 15
# Processed frame 643.0/-2562047788015215
# GPU utilization: 15
# Processed frame 644.0/-2562047788015215
# GPU utilization: 15
# Processed frame 645.0/-2562047788015215
# GPU utilization: 15
# Processed frame 646.0/-2562047788015215
# GPU utilization: 15
# Processed frame 647.0/-2562047788015215
# GPU utilization: 15
# Processed frame 648.0/-2562047788015215
# GPU utilization: 15
# Processed frame 649.0/-2562047788015215
# GPU utilization: 15
# Processed frame 650.0/-2562047788015215
# GPU utilization: 15
# Processed frame 651.0/-2562047788015215
# GPU utilization: 15
# Processed frame 652.0/-2562047788015215
# GPU utilization: 15
# Processed frame 653.0/-2562047788015215
# GPU utilization: 15
# Processed frame 654.0/-2562047788015215
# GPU utilization: 15
# Processed frame 655.0/-2562047788015215
# GPU utilization: 15
# Processed frame 656.0/-2562047788015215
# GPU utilization: 15
# Processed frame 657.0/-2562047788015215
# GPU utilization: 15
# Processed frame 658.0/-2562047788015215
# GPU utilization: 21
# Processed frame 659.0/-2562047788015215
# GPU utilization: 21
# Processed frame 660.0/-2562047788015215
# GPU utilization: 21
# Processed frame 661.0/-2562047788015215
# GPU utilization: 21
# Processed frame 662.0/-2562047788015215
# GPU utilization: 21
# Processed frame 663.0/-2562047788015215
# GPU utilization: 21
# Processed frame 664.0/-2562047788015215
# GPU utilization: 21
# Processed frame 665.0/-2562047788015215
# GPU utilization: 21
# Processed frame 666.0/-2562047788015215
# GPU utilization: 21
# Processed frame 667.0/-2562047788015215
# GPU utilization: 21
# Processed frame 668.0/-2562047788015215
# GPU utilization: 21
# Processed frame 669.0/-2562047788015215
# GPU utilization: 21
# Processed frame 670.0/-2562047788015215
# GPU utilization: 21
# Processed frame 671.0/-2562047788015215
# GPU utilization: 21
# Processed frame 672.0/-2562047788015215
# GPU utilization: 21
# Processed frame 673.0/-2562047788015215
# GPU utilization: 16
# Processed frame 674.0/-2562047788015215
# GPU utilization: 16
# Processed frame 675.0/-2562047788015215
# GPU utilization: 16
# Processed frame 676.0/-2562047788015215
# GPU utilization: 16
# Processed frame 677.0/-2562047788015215
# GPU utilization: 16
# Processed frame 678.0/-2562047788015215
# GPU utilization: 16
# Processed frame 679.0/-2562047788015215
# GPU utilization: 16
# Processed frame 680.0/-2562047788015215
# GPU utilization: 16
# Processed frame 681.0/-2562047788015215
# GPU utilization: 16
# Processed frame 682.0/-2562047788015215
# GPU utilization: 16
# Processed frame 683.0/-2562047788015215
# GPU utilization: 16
# Processed frame 684.0/-2562047788015215
# GPU utilization: 16
# Processed frame 685.0/-2562047788015215
# GPU utilization: 16
# Processed frame 686.0/-2562047788015215
# GPU utilization: 16
# Processed frame 687.0/-2562047788015215
# GPU utilization: 16
# Processed frame 688.0/-2562047788015215
# GPU utilization: 16
# Processed frame 689.0/-2562047788015215
# GPU utilization: 16
# Processed frame 690.0/-2562047788015215
# GPU utilization: 18
# Processed frame 691.0/-2562047788015215
# GPU utilization: 18
# Processed frame 692.0/-2562047788015215
# GPU utilization: 18
# Processed frame 693.0/-2562047788015215
# GPU utilization: 18
# Processed frame 694.0/-2562047788015215
# GPU utilization: 18
# Processed frame 695.0/-2562047788015215
# GPU utilization: 18
# Processed frame 696.0/-2562047788015215
# GPU utilization: 18
# Processed frame 697.0/-2562047788015215
# GPU utilization: 18
# Processed frame 698.0/-2562047788015215
# GPU utilization: 18
# Processed frame 699.0/-2562047788015215
# GPU utilization: 18
# Processed frame 700.0/-2562047788015215
# GPU utilization: 18
# Processed frame 701.0/-2562047788015215
# GPU utilization: 18
# Processed frame 702.0/-2562047788015215
# GPU utilization: 18
# Processed frame 703.0/-2562047788015215
# GPU utilization: 18
# Processed frame 704.0/-2562047788015215
# GPU utilization: 18
# Processed frame 705.0/-2562047788015215
# GPU utilization: 18
# Processed frame 706.0/-2562047788015215
# GPU utilization: 23
# Processed frame 707.0/-2562047788015215
# GPU utilization: 23
# Processed frame 708.0/-2562047788015215
# GPU utilization: 23
# Processed frame 709.0/-2562047788015215
# GPU utilization: 23
# Processed frame 710.0/-2562047788015215
# GPU utilization: 23
# Processed frame 711.0/-2562047788015215
# GPU utilization: 23
# Processed frame 712.0/-2562047788015215
# GPU utilization: 23
# Processed frame 713.0/-2562047788015215
# GPU utilization: 23
# Processed frame 714.0/-2562047788015215
# GPU utilization: 23
# Processed frame 715.0/-2562047788015215
# GPU utilization: 23
# Processed frame 716.0/-2562047788015215
# GPU utilization: 23
# Processed frame 717.0/-2562047788015215
# GPU utilization: 23
# Processed frame 718.0/-2562047788015215
# GPU utilization: 23
# Processed frame 719.0/-2562047788015215
# GPU utilization: 23
# Processed frame 720.0/-2562047788015215
# GPU utilization: 23
# Processed frame 721.0/-2562047788015215
# GPU utilization: 23
# Processed frame 722.0/-2562047788015215
# GPU utilization: 23
# Processed frame 723.0/-2562047788015215
# GPU utilization: 23
# Processed frame 724.0/-2562047788015215
# GPU utilization: 23
# Processed frame 725.0/-2562047788015215
# GPU utilization: 20
# Processed frame 726.0/-2562047788015215
# GPU utilization: 20
# Processed frame 727.0/-2562047788015215
# GPU utilization: 20
# Processed frame 728.0/-2562047788015215
# GPU utilization: 20
# Processed frame 729.0/-2562047788015215
# GPU utilization: 20
# Processed frame 730.0/-2562047788015215
# GPU utilization: 20
# Processed frame 731.0/-2562047788015215
# GPU utilization: 20
# Processed frame 732.0/-2562047788015215
# GPU utilization: 20
# Processed frame 733.0/-2562047788015215
# GPU utilization: 20
# Processed frame 734.0/-2562047788015215
# GPU utilization: 20
# Processed frame 735.0/-2562047788015215
# GPU utilization: 20
# Processed frame 736.0/-2562047788015215
# GPU utilization: 20
# Processed frame 737.0/-2562047788015215
# GPU utilization: 20
# Processed frame 738.0/-2562047788015215
# GPU utilization: 20
# Processed frame 739.0/-2562047788015215
# GPU utilization: 20
# 1/1 [==============================] - 0s 28ms/step
# with GPU
# Processed frame 740.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 741.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 20ms/step
# with GPU
# Processed frame 742.0/-2562047788015215
# GPU utilization: 14
# Processed frame 743.0/-2562047788015215
# GPU utilization: 14
# Processed frame 744.0/-2562047788015215
# GPU utilization: 14
# Processed frame 745.0/-2562047788015215
# GPU utilization: 14
# Processed frame 746.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 17ms/step
# with GPU
# Processed frame 747.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 748.0/-2562047788015215
# GPU utilization: 15
# Processed frame 749.0/-2562047788015215
# GPU utilization: 15
# Processed frame 750.0/-2562047788015215
# GPU utilization: 15
# Processed frame 751.0/-2562047788015215
# GPU utilization: 15
# Processed frame 752.0/-2562047788015215
# GPU utilization: 15
# Processed frame 753.0/-2562047788015215
# GPU utilization: 15
# Processed frame 754.0/-2562047788015215
# GPU utilization: 15
# Processed frame 755.0/-2562047788015215
# GPU utilization: 15
# Processed frame 756.0/-2562047788015215
# GPU utilization: 15
# Processed frame 757.0/-2562047788015215
# GPU utilization: 15
# Processed frame 758.0/-2562047788015215
# GPU utilization: 15
# Processed frame 759.0/-2562047788015215
# GPU utilization: 15
# Processed frame 760.0/-2562047788015215
# GPU utilization: 15
# Processed frame 761.0/-2562047788015215
# GPU utilization: 15
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 762.0/-2562047788015215
# GPU utilization: 15
# Processed frame 763.0/-2562047788015215
# GPU utilization: 15
# Processed frame 764.0/-2562047788015215
# GPU utilization: 15
# Processed frame 765.0/-2562047788015215
# GPU utilization: 15
# Processed frame 766.0/-2562047788015215
# GPU utilization: 15
# Processed frame 767.0/-2562047788015215
# GPU utilization: 15
# Processed frame 768.0/-2562047788015215
# GPU utilization: 15
# Processed frame 769.0/-2562047788015215
# GPU utilization: 15
# Processed frame 770.0/-2562047788015215
# GPU utilization: 15
# Processed frame 771.0/-2562047788015215
# GPU utilization: 15
# Processed frame 772.0/-2562047788015215
# GPU utilization: 15
# Processed frame 773.0/-2562047788015215
# GPU utilization: 15
# Processed frame 774.0/-2562047788015215
# GPU utilization: 15
# Processed frame 775.0/-2562047788015215
# GPU utilization: 15
# Processed frame 776.0/-2562047788015215
# GPU utilization: 15
# Processed frame 777.0/-2562047788015215
# GPU utilization: 15
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 778.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 17ms/step
# with GPU
# Processed frame 779.0/-2562047788015215
# GPU utilization: 16
# Processed frame 780.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 20ms/step
# with GPU
# Processed frame 781.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 18ms/step
# with GPU
# Processed frame 782.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 20ms/step
# with GPU
# Processed frame 783.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 18ms/step
# with GPU
# Processed frame 784.0/-2562047788015215
# GPU utilization: 15
# 1/1 [==============================] - 0s 20ms/step
# with GPU
# Processed frame 785.0/-2562047788015215
# GPU utilization: 15
# 1/1 [==============================] - 0s 20ms/step
# with GPU
# Processed frame 786.0/-2562047788015215
# GPU utilization: 15
# Processed frame 787.0/-2562047788015215
# GPU utilization: 15
# Processed frame 788.0/-2562047788015215
# GPU utilization: 15
# Processed frame 789.0/-2562047788015215
# GPU utilization: 15
# Processed frame 790.0/-2562047788015215
# GPU utilization: 15
# Processed frame 791.0/-2562047788015215
# GPU utilization: 15
# Processed frame 792.0/-2562047788015215
# GPU utilization: 15
# Processed frame 793.0/-2562047788015215
# GPU utilization: 15
# Processed frame 794.0/-2562047788015215
# GPU utilization: 15
# Processed frame 795.0/-2562047788015215
# GPU utilization: 15
# Processed frame 796.0/-2562047788015215
# GPU utilization: 15
# 1/1 [==============================] - 0s 21ms/step
# with GPU
# Processed frame 797.0/-2562047788015215
# GPU utilization: 15
# Processed frame 798.0/-2562047788015215
# GPU utilization: 15
# Processed frame 799.0/-2562047788015215
# GPU utilization: 15
# Processed frame 800.0/-2562047788015215
# GPU utilization: 15
# Processed frame 801.0/-2562047788015215
# GPU utilization: 15
# Processed frame 802.0/-2562047788015215
# GPU utilization: 15
# Processed frame 803.0/-2562047788015215
# GPU utilization: 15
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 804.0/-2562047788015215
# GPU utilization: 15
# Processed frame 805.0/-2562047788015215
# GPU utilization: 15
# Processed frame 806.0/-2562047788015215
# GPU utilization: 15
# 1/1 [==============================] - 0s 17ms/step
# with GPU
# Processed frame 807.0/-2562047788015215
# GPU utilization: 16
# Processed frame 808.0/-2562047788015215
# GPU utilization: 16
# Processed frame 809.0/-2562047788015215
# GPU utilization: 16
# Processed frame 810.0/-2562047788015215
# GPU utilization: 16
# Processed frame 811.0/-2562047788015215
# GPU utilization: 16
# Processed frame 812.0/-2562047788015215
# GPU utilization: 16
# Processed frame 813.0/-2562047788015215
# GPU utilization: 16
# Processed frame 814.0/-2562047788015215
# GPU utilization: 16
# Processed frame 815.0/-2562047788015215
# GPU utilization: 16
# Processed frame 816.0/-2562047788015215
# GPU utilization: 16
# Processed frame 817.0/-2562047788015215
# GPU utilization: 16
# Processed frame 818.0/-2562047788015215
# GPU utilization: 16
# Processed frame 819.0/-2562047788015215
# GPU utilization: 16
# Processed frame 820.0/-2562047788015215
# GPU utilization: 16
# Processed frame 821.0/-2562047788015215
# GPU utilization: 16
# Processed frame 822.0/-2562047788015215
# GPU utilization: 16
# Processed frame 823.0/-2562047788015215
# GPU utilization: 16
# Processed frame 824.0/-2562047788015215
# GPU utilization: 16
# Processed frame 825.0/-2562047788015215
# GPU utilization: 16
# Processed frame 826.0/-2562047788015215
# GPU utilization: 16
# Processed frame 827.0/-2562047788015215
# GPU utilization: 16
# Processed frame 828.0/-2562047788015215
# GPU utilization: 16
# Processed frame 829.0/-2562047788015215
# GPU utilization: 16
# Processed frame 830.0/-2562047788015215
# GPU utilization: 16
# Processed frame 831.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 20ms/step
# with GPU
# Processed frame 832.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 833.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 18ms/step
# with GPU
# Processed frame 834.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 21ms/step
# with GPU
# Processed frame 835.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 22ms/step
# with GPU
# Processed frame 836.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 18ms/step
# with GPU
# Processed frame 837.0/-2562047788015215
# GPU utilization: 14
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 838.0/-2562047788015215
# GPU utilization: 14
# Processed frame 839.0/-2562047788015215
# GPU utilization: 14
# Processed frame 840.0/-2562047788015215
# GPU utilization: 14
# Processed frame 841.0/-2562047788015215
# GPU utilization: 14
# Processed frame 842.0/-2562047788015215
# GPU utilization: 16
# Processed frame 843.0/-2562047788015215
# GPU utilization: 16
# Processed frame 844.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 20ms/step
# with GPU
# Processed frame 845.0/-2562047788015215
# GPU utilization: 16
# Processed frame 846.0/-2562047788015215
# GPU utilization: 16
# Processed frame 847.0/-2562047788015215
# GPU utilization: 16
# Processed frame 848.0/-2562047788015215
# GPU utilization: 16
# 1/1 [==============================] - 0s 19ms/step
# with GPU
# Processed frame 849.0/-2562047788015215
# GPU utilization: 16
# Processed frame 850.0/-2562047788015215
# GPU utilization: 16
# Processed frame 851.0/-2562047788015215
# GPU utilization: 16
# Processed frame 852.0/-2562047788015215
# GPU utilization: 16
# Processed frame 853.0/-2562047788015215
# GPU utilization: 16
# Processed frame 854.0/-2562047788015215
# GPU utilization: 17
# Processed frame 855.0/-2562047788015215
# GPU utilization: 17
# Processed frame 856.0/-2562047788015215
# GPU utilization: 17
# Processed frame 857.0/-2562047788015215
# GPU utilization: 17
# Processed frame 858.0/-2562047788015215
# GPU utilization: 17
# Processed frame 859.0/-2562047788015215
